# %% [markdown]
# # Facial Keypoint Detection
#
# Welcome back for exercise 9! As we told you, the exercises of this lecture can be subdivided into mainly two parts. The first part in which we re-invented the wheel and implemented the most important methods on our own and the second part, where we start using existing libraries (that already have implemented all the methods). It's about time to start playing around with more complex network architectures.
#
# We've already entered stage two, but with the introduction of convolution neural networks this week, we are given a very powerful tool that we want to explore in this exercises. Therefore, in this week's exercise your task is to build a convolution neural network to perform facial keypoint detection.
#
# Before we start, let's take a look at some example images and corresponding facial keypoints:
#
# <img src='images/key_pts_example.png' width=70% height=70%/>
#
# The facial keypoints (also called facial landmarks) are the small magenta dots shown on each of the faces in the images above. These keypoints mark important areas of the face: the eyes, corners of the mouth, the nose, etc. and are relevant for a variety of computer vision tasks, such as face filters, emotion recognition, pose recognition, and more.

# %% [markdown]
# ## (Optional) Mount folder in Colab
#
# Uncomment thefollowing cell to mount your gdrive if you are using the notebook in google colab:

# %%
# Use the following lines if you want to use Google Colab
# We presume you created a folder "i2dl" within your main drive folder, and put the exercise there.
# NOTE: terminate all other colab sessions that use GPU!
# NOTE 2: Make sure the correct exercise folder (e.g exercise_09) is given.

"""
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/i2dl/exercise_09'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
print(sorted(os.listdir()))

# Relevant packages. NOTE: Be patient, it might take a few minutes.
# !python -m pip install tensorboard==2.9.1 pytorch-lightning==1.6.0 torchtext
"""
# Out:
# "\nfrom google.colab import drive\nimport os\n\ngdrive_path='/content/gdrive/MyDrive/i2dl/exercise_09'\n\n# This will mount your google drive under 'MyDrive'\ndrive.mount('/content/gdrive', force_remount=True)\n# In order to access the files in this notebook we have to navigate to the correct folder\nos.chdir(gdrive_path)\n# Check manually if all files are present\nprint(sorted(os.listdir()))\n\n# Relevant packages. NOTE: Be patient, it might take a few minutes.\n!python -m pip install tensorboard==2.9.1 pytorch-lightning==1.6.0 torchtext\n"

# %% [markdown]
# # 1. Preparation
#
# ## Imports

# %%
import os
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from exercise_code.data.facial_keypoints_dataset import FacialKeypointsDataset
from exercise_code.networks.keypoint_nn import (
    DummyKeypointModel,
    KeypointModel
)
from exercise_code.util import (
    show_all_keypoints,
    save_model,
)
from exercise_code.tests import test_keypoint_nn

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# <div class="alert alert-warning">
#     <h3>Note: Google Colab</h3>
#     <p>
# In case you don't have a GPU, you can run this notebook on Google Colab where you can access a GPU for free, but you can also run this notebook on your CPU.
#          </p>
# </div>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## Load and Visualize Data
# To load the data, we have already prepared a Pytorch Dataset class `FacialKeypointsDataset` for you. You can find it in `exercise_code/data/facial_keypoints_dataset.py`. Run the following cell to download the data and initialize your dataset:

# %%
download_url = "https://vision.in.tum.de/webshare/g/i2dl/facial_keypoints.zip"
i2dl_exercises_path = os.path.dirname(os.path.abspath(os.getcwd()))
data_root = os.path.join(i2dl_exercises_path, "datasets", "facial_keypoints")
train_dataset = FacialKeypointsDataset(
    train=True,
    transform=transforms.ToTensor(),
    root=data_root,
    download_url=download_url,
)
val_dataset = FacialKeypointsDataset(
    train=False,
    transform=transforms.ToTensor(),
    root=data_root,
)

print("Number of training samples:", len(train_dataset))
print("Number of validation samples:", len(val_dataset))
# Out:
# Number of training samples: 1546
# Number of validation samples: 298

# %% [markdown]
# Each sample in our dataset is a dict `{"image": image, "keypoints": keypoints}`, where
#  * `image` is a [0-1]-normalized gray-scale image of size 96x96, represented by a torch tensor of shape (CxHxW) with C=1, H=96, W=96
#     <img style="float: right;" src='images/key_pts_expl.png' width=50% height=50%/>
#  * `keypoints` is the list of K facial keypoints, stored in a torch tensor of shape (Kx2). We have K=15 keypoints that stand for:
#    * keypoints[0]: Center of the left eye
#    * keypoints[1]: Center of the right eye
#    * keypoints[2]: Left eye inner corner
#    * keypoints[3]: Left eye outer corner
#    * keypoints[4]: Right eye inner corner
#    * keypoints[5]: Right eye outer corner
#    * keypoints[6]: Left eyebrow inner end
#    * keypoints[7]: Left eyebrow outer end
#    * keypoints[8]: Right eyebrow inner end
#    * keypoints[9]: Right eyebrow outer end
#    * keypoints[10]: Nose tip
#    * keypoints[11]: Mouth left corner
#    * keypoints[12]: Mouth right corner
#    * keypoints[13]: Mouth center top lip
#    * keypoints[14]: Mouth center bottom lip
#
# Each individual facial keypoint is represented by two coordinates (x,y) that specify the horizontal and vertical location of the keypoint respectively. All keypoint values are normalized to [-1,1], such that:
#    * (x=-1,y=-1) corresponds to the top left corner,
#    * (x=-1,y=1) to the bottom left corner,
#    * (x=1,y=-1) to the top right corner,
#    * (x=1,y=1) to the bottom right corner,
#    * and (x=0,y=0) to the center of the image.
#
#
# The data downloaded is already preprocessed and hence there is no need to apply transformations in order to prepare the data. Of course, feel free to apply training transformations to improve your performance such as e.g. flipping the training images. </br>
#
# NOTE: Do not forget that these transformations (data augmentation) are only applied to your training data. Your validation and test set remain untouched. </br>
#
# Also, when applying transformations such as flipping, make sure that the predicted coordinates of your keypoints change accordingly.
#
# Let's have a look at the first training sample to get a better feeling for the dataset:

# %%
image, keypoints = train_dataset[0]["image"], train_dataset[0]["keypoints"]
print("Shape of the image:", image.size())
print("Smallest value in the image:", torch.min(image))
print("Largest value in the image:", torch.max(image))
print(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 image, keypoints = train_dataset[0]["image"], train_dataset[0]["keypoints"]
#       2 print("Shape of the image:", image.size())
#       3 print("Smallest value in the image:", torch.min(image))
#
# File ~/Desktop/i2dl_exercises/exercise_09/exercise_code/data/facial_keypoints_dataset.py:45, in FacialKeypointsDataset.__getitem__(self, idx)
#      43 keypoints = self._get_keypoints(idx, self.key_pts_frame)
#      44 if self.transform:
# ---> 45     image = self.transform(image)
#      46 return {'image': image, 'keypoints': keypoints}
#
# File ~/miniconda3/envs/i2dl/lib/python3.10/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~/miniconda3/envs/i2dl/lib/python3.10/site-packages/torch/nn/modules/module.py:1502, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1500     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1501 else:
# -> 1502     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/i2dl/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._call_impl(self, *args, **kwargs)
#    1506 # If we don't have any hooks, we want to skip the rest of the logic in
#    1507 # this function, and just call forward.
#    1508 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1509         or _global_backward_pre_hooks or _global_backward_hooks
#    1510         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1511     return forward_call(*args, **kwargs)
#    1512 # Do not call functions when jit is used
#    1513 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/i2dl/lib/python3.10/site-packages/torchvision/transforms/transforms.py:979, in RandomResizedCrop.forward(self, img)
#     971 def forward(self, img):
#     972     """
#     973     Args:
#     974         img (PIL Image or Tensor): Image to be cropped and resized.
#    (...)
#     977         PIL Image or Tensor: Randomly cropped and resized image.
#     978     """
# --> 979     i, j, h, w = self.get_params(img, self.scale, self.ratio)
#     980     return F.resized_crop(img, i, j, h, w, self.size, self.interpolation, antialias=self.antialias)
#
# File ~/miniconda3/envs/i2dl/lib/python3.10/site-packages/torchvision/transforms/transforms.py:940, in RandomResizedCrop.get_params(img, scale, ratio)
#     927 @staticmethod
#     928 def get_params(img: Tensor, scale: List[float], ratio: List[float]) -> Tuple[int, int, int, int]:
#     929     """Get parameters for ``crop`` for a random sized crop.
#     930
#     931     Args:
#    (...)
#     938         sized crop.
#     939     """
# --> 940     _, height, width = F.get_dimensions(img)
#     941     area = height * width
#     943     log_ratio = torch.log(torch.tensor(ratio))
#
# File ~/miniconda3/envs/i2dl/lib/python3.10/site-packages/torchvision/transforms/functional.py:78, in get_dimensions(img)
#      75 if isinstance(img, torch.Tensor):
#      76     return F_t.get_dimensions(img)
# ---> 78 return F_pil.get_dimensions(img)
#
# File ~/miniconda3/envs/i2dl/lib/python3.10/site-packages/torchvision/transforms/_functional_pil.py:31, in get_dimensions(img)
#      29     width, height = img.size
#      30     return [channels, height, width]
# ---> 31 raise TypeError(f"Unexpected type {type(img)}")
#
# TypeError: Unexpected type <class 'numpy.ndarray'>

# %%
keypoints = train_dataset[0]["keypoints"]
print(keypoints)
# Out:
# tensor([[ 0.4685, -0.2319],
#         [-0.4253, -0.1953],
#         [ 0.2908, -0.2214],
#         [ 0.5992, -0.2214],
#         [-0.2685, -0.2109],
#         [-0.5873, -0.1900],
#         [ 0.1967, -0.3827],
#         [ 0.7656, -0.4295],
#         [-0.2035, -0.3758],
#         [-0.7389, -0.3573],
#         [ 0.0086,  0.2333],
#         [ 0.4163,  0.6620],
#         [-0.3521,  0.6985],
#         [ 0.0138,  0.6045],
#         [ 0.0190,  0.9076]])

# %% [markdown]
# In `exercise_code/util/vis_utils.py` we also provide you with a function `show_all_keypoints()` that takes in an image and keypoints and displays where the predicted keypoints are in the image. Let's use it to plot the first few images of our training set:
#
# **Note:** if your kernel dies when running the following cell, please uncomment the last line of the imports cell `os.environ['KMP_DUPLICATE_LIB_OK']='True'`and try it again.

# %%
def show_keypoints(dataset, num_samples=3):
    for i in range(num_samples):
        image = dataset[i]["image"]
        key_pts = dataset[i]["keypoints"]
        show_all_keypoints(image, key_pts)


show_keypoints(train_dataset)

# %% [markdown]
# # 2. Facial Keypoint Detection
# Your task is to define and train a model for facial keypoint detection.
#
# The facial keypoint detection task can be seen as a regression problem, where the goal is to predict 30 different values that correspond to the 15 facial keypoint locations. Thus, we need to build a network that gets a (1x96x96) image as input and predicts 30 continuous outputs between [-1,1].
#
# ## Dummy Model
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>In <code>exercise_code/networks/keypoint_nn.py</code> we defined a naive <code>DummyKeypointModel</code>, which always predicts the keypoints of the first training image in the dataset. Let's try it on a few images and visualize our predictions in red:
#  </p>
# </div>

# %%
def show_keypoint_predictions(model, dataset, num_samples=3):
    for i in range(num_samples):
        image = dataset[i]["image"].to(device)
        key_pts = dataset[i]["keypoints"].to(device)
        predicted_keypoints = torch.squeeze(model(image).detach()).view(15, 2)
        show_all_keypoints(image, key_pts, predicted_keypoints)

# %%
dummy_model = DummyKeypointModel()
show_keypoint_predictions(dummy_model, train_dataset)

# %% [markdown]
# As we see, the model predicts the first sample perfectly, but for the remaining samples the predictions are quite off.
#
# ## Loss and Metrics
#
# To measure the quality of the model's predictions, we will use the mean squared error (https://en.wikipedia.org/wiki/Mean_squared_error), summed up over all 30 keypoint locations. In PyTorch, the mean squared error is defined in `torch.nn.MSELoss()`, and we can use it like this:

# %%
loss_fn = torch.nn.MSELoss()
for i in range(3):
    image = train_dataset[i]["image"]
    keypoints = train_dataset[i]["keypoints"]
    predicted_keypoints = torch.squeeze(dummy_model(image)).view(15, 2)
    loss = loss_fn(keypoints, predicted_keypoints)
    print("Loss on image %d:" % i, loss)
# Out:
# Loss on image 0: tensor(9.3016e-10)
# Loss on image 1: tensor(0.0094)
# Loss on image 2: tensor(0.0102)

# %% [markdown]
# As expected, our dummy model achieves a loss close to 0 on the first sample, but on all other samples the loss is quite high.
#
# To obtain an evaluation score (in the notebook and on the submission server), we will use the following function:

# %%
def evaluate_model(model, dataset):
    model.eval()
    model.to(device)
    criterion = torch.nn.MSELoss()
    dataloader = DataLoader(dataset, batch_size=1, shuffle=False)
    loss = 0
    for batch in dataloader:
        image, keypoints = batch["image"].to(device), batch["keypoints"].to(device)
        predicted_keypoints = model(image).view(-1,15,2).to(device)
        loss += criterion(
            torch.squeeze(keypoints), torch.squeeze(predicted_keypoints)
        ).item()
    return 1.0 / (2 * (loss / len(dataloader)))


print("Score of the Dummy Model:", evaluate_model(dummy_model, val_dataset))
# Out:
# Score of the Dummy Model: 60.195747455122635

# %% [markdown]
# **To pass the assignment, you will need to achieve a score of at least 100**. As you can see, the score is calculated from the average loss, so **your average loss needs to be lower than 0.005**. Our dummy model only gets a score of around 60, so you will have to come up with a better model.

# %% [markdown]
# ## Step 1: Design your own model
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p> Now it is your turn to build your own model. To do so, you need to design a convolution neural network that takes images of size (Nx1x96x96) as input and produces outputs of shape (Nx30) in the range [-1,1]. Therefore, implement the <code>KeypointModel</code> class in <code>exercise_code/networks/keypoint_nn.py</code>.
#     </p>
# </div>
#
# Recall that CNN's are defined by a few types of layers:
# * Convolution layers
# * Max-pooling layers
# * Fully-connected layers
#
# You can design your network however you want, but we strongly suggest to include multiple convolution layers. You are also encouraged to use things like dropout and batch normalization to stabilize and regularize your network. If you want to build a really competitive model, have a look at some literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf).
#
# #### Define your model in the provided file
# `exercise_code/networks/keypoint_nn.py` file
#
# This file is mostly empty but contains the expected class name, and the methods that your model needs to implement (only `forward()` basically). You are also free to decide whether you want to use PyTorch Lightning or not.
# The only rules your model design has to follow are:
# * Inherit from either `torch.nn.Module` or `pytorch_lightning.LightningModule`
# * Perform the forward pass in forward(), predicting keypoints of shape (Nx30) for images of shape (Nx1x96x96)
# * Have less than 5 million parameters
# * Have a model size of less than 20MB after saving
#
# Furthermore, you need to pass all your hyperparameters to the model in a single dictionary:

# %%
hparams = {
    # TODO: if you have any model arguments/hparams, define them here
    "n_hidden": 224,
    "learning_rate": 1e-3,
    "batch_size": 64,
    "num_filters": 32,
    "kernel_size": 3,
    "stride": 1,
    "padding": 1,
    "weight_decay":1e-8
}

# %% [markdown]
# To test whether your model follows the basic rules, run the following cell:

# %%
model = KeypointModel(hparams)
test_keypoint_nn(model)
# Out:
# KeypointShapeTest passed.
# ParamCountTest passed. Your model has 2.755 mio. params.
# FileSizeTest passed. Your model is 11.0 MB large
# All tests passed for your model. Tests passed: 3/3

# %% [markdown]
# ## Step 2: Train your model
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p> In addition to the network itself, you will also need to write the code for the model training. You can use PyTorch Lightning for that, or you can also write it yourself in standard PyTorch.
#     </p>
# </div>
#
# **Hints:**
# * Use `torch.nn.MSELoss()` as loss function.
#
# * You have two options for training code:
#     - (Recommended) Use a straightforward training scheme. See 1.pytorch.ipynb from ex07.
#     - (Not Recommended, especially for colab user) Use the Trainer() class, to utilize the beauty of pytorch-lightning. See 3.pytorch_lightning.ipynb from ex07. NOTE(!!!): To prevent a common bug, send the dataloaders to the trainer, and not to the pytorch-lightning class itself.
#     - Don't call your model anything else besides "model", unless you notice that you'll need to modify the model name in the upcoming cells.
#     - You could refer to the training scheme from exercise_08 to complete your code. Understanding this pipeline is crucial for future works in deep learning.

# %%
########################################################################
# TODO - Train Your Model                                              #
########################################################################
import torch.optim as optim
from torch import nn
from exercise_code.networks.keypoint_nn import KeypointModel

model = KeypointModel(hparams)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=hparams["learning_rate"],betas=[0.9,0.999],weight_decay=hparams["weight_decay"])
train_dataloader = DataLoader(train_dataset, batch_size=hparams["batch_size"], shuffle=True)

def train_model(train_dataloader,num_epoch):
    train_len = len(train_dataloader)
    for epoch in range(num_epoch):
        train_loss = 0.0
        for batch_idx, batch in enumerate(train_dataloader):
            images, keypoints = batch["image"], batch["keypoints"]
            keypoints = keypoints.view(keypoints.size(0), -1)
            keypoints = keypoints.type(torch.FloatTensor).to(device)
            images = images.type(torch.FloatTensor).to(device)
            predicted_keypoints = model(images)
            loss = nn.MSELoss()(predicted_keypoints, keypoints)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            if batch_idx!= 0:
                print('train_epoch:{}|batch_idx:{}|train_loss:{}'.format(epoch+1, batch_idx+1, train_loss/((train_len*epoch)+batch_idx+1)))
            
train_model(train_dataloader, 30)
pass

########################################################################
#                           END OF YOUR CODE                           #
########################################################################
# Out:
# train_epoch:1|batch_idx:2|train_loss:0.13305866345763206
# train_epoch:1|batch_idx:3|train_loss:0.122178981701533
# train_epoch:1|batch_idx:4|train_loss:0.11267345026135445
# train_epoch:1|batch_idx:5|train_loss:0.10513263493776322
# train_epoch:1|batch_idx:6|train_loss:0.10007683311899503
# train_epoch:1|batch_idx:7|train_loss:0.09628873531307493
# train_epoch:1|batch_idx:8|train_loss:0.09360279608517885
# train_epoch:1|batch_idx:9|train_loss:0.09126688457197613
# train_epoch:1|batch_idx:10|train_loss:0.08951138779520988
# train_epoch:1|batch_idx:11|train_loss:0.08809983730316162
# train_epoch:1|batch_idx:12|train_loss:0.0867285883675019
# train_epoch:1|batch_idx:13|train_loss:0.08540033205197407
# train_epoch:1|batch_idx:14|train_loss:0.08427094402057785
# train_epoch:1|batch_idx:15|train_loss:0.0834447259704272
# train_epoch:1|batch_idx:16|train_loss:0.08281876984983683
# train_epoch:1|batch_idx:17|train_loss:0.08196664601564407
# train_epoch:1|batch_idx:18|train_loss:0.08117419150140551
# train_epoch:1|batch_idx:19|train_loss:0.08065344393253326
# train_epoch:1|batch_idx:20|train_loss:0.08023255430161953
# train_epoch:1|batch_idx:21|train_loss:0.07977345195554551
# train_epoch:1|batch_idx:22|train_loss:0.0794188187203624
# train_epoch:1|batch_idx:23|train_loss:0.07896873030973517
# train_epoch:1|batch_idx:24|train_loss:0.0786654365559419
# train_epoch:1|batch_idx:25|train_loss:0.07811708360910416
# train_epoch:2|batch_idx:2|train_loss:0.005104410427588003
# train_epoch:2|batch_idx:3|train_loss:0.007513674508248057
# train_epoch:2|batch_idx:4|train_loss:0.009687935226950151
# train_epoch:2|batch_idx:5|train_loss:0.0117579052845637
# train_epoch:2|batch_idx:6|train_loss:0.013708155722387375
# train_epoch:2|batch_idx:7|train_loss:0.015358238946646452
# train_epoch:2|batch_idx:8|train_loss:0.01702745191075585
# train_epoch:2|batch_idx:9|train_loss:0.018560048850143656
# train_epoch:2|batch_idx:10|train_loss:0.01999895636524473
# train_epoch:2|batch_idx:11|train_loss:0.0212598643783066
# train_epoch:2|batch_idx:12|train_loss:0.022551007367469168
# train_epoch:2|batch_idx:13|train_loss:0.023742334034882094
# train_epoch:2|batch_idx:14|train_loss:0.024864067633946735
# train_epoch:2|batch_idx:15|train_loss:0.025931536220014095
# train_epoch:2|batch_idx:16|train_loss:0.026951855820853535
# train_epoch:2|batch_idx:17|train_loss:0.027942486462138948
# train_epoch:2|batch_idx:18|train_loss:0.028937976200913273
# train_epoch:2|batch_idx:19|train_loss:0.02985059182074937
# train_epoch:2|batch_idx:20|train_loss:0.030709403918849097
# train_epoch:2|batch_idx:21|train_loss:0.03153325552525728
# train_epoch:2|batch_idx:22|train_loss:0.03232811755956488
# train_epoch:2|batch_idx:23|train_loss:0.03302943675468365
# train_epoch:2|batch_idx:24|train_loss:0.033757603898340344
# train_epoch:2|batch_idx:25|train_loss:0.0343834887444973
# train_epoch:3|batch_idx:2|train_loss:0.002608549422942675
# train_epoch:3|batch_idx:3|train_loss:0.003855762335489381
# train_epoch:3|batch_idx:4|train_loss:0.005060897105269962
# train_epoch:3|batch_idx:5|train_loss:0.006201141530817206
# train_epoch:3|batch_idx:6|train_loss:0.007271272795540946
# train_epoch:3|batch_idx:7|train_loss:0.008287170999928525
# train_epoch:3|batch_idx:8|train_loss:0.009332234617964974
# train_epoch:3|batch_idx:9|train_loss:0.010330198174816067
# train_epoch:3|batch_idx:10|train_loss:0.011266732836763065
# train_epoch:3|batch_idx:11|train_loss:0.012142599483982462
# train_epoch:3|batch_idx:12|train_loss:0.013008774768921637
# train_epoch:3|batch_idx:13|train_loss:0.013853484439471412
# train_epoch:3|batch_idx:14|train_loss:0.014660453191027045
# train_epoch:3|batch_idx:15|train_loss:0.01548797064102613
# train_epoch:3|batch_idx:16|train_loss:0.016297137308301346
# train_epoch:3|batch_idx:17|train_loss:0.017053902482808525
# train_epoch:3|batch_idx:18|train_loss:0.017797067980555928
# train_epoch:3|batch_idx:19|train_loss:0.01848021743522174
# train_epoch:3|batch_idx:20|train_loss:0.0191495381295681
# train_epoch:3|batch_idx:21|train_loss:0.01982669259460879
# train_epoch:3|batch_idx:22|train_loss:0.02048027753416035
# train_epoch:3|batch_idx:23|train_loss:0.021117304183848915
# train_epoch:3|batch_idx:24|train_loss:0.02174411774487109
# train_epoch:3|batch_idx:25|train_loss:0.02227649172147115
# train_epoch:4|batch_idx:2|train_loss:0.0017264877240379135
# train_epoch:4|batch_idx:3|train_loss:0.002555709045666915
# train_epoch:4|batch_idx:4|train_loss:0.0033607740379587004
# train_epoch:4|batch_idx:5|train_loss:0.0041401548311114315
# train_epoch:4|batch_idx:6|train_loss:0.004877504743175742
# train_epoch:4|batch_idx:7|train_loss:0.005612774502213408
# train_epoch:4|batch_idx:8|train_loss:0.006361988563853574
# train_epoch:4|batch_idx:9|train_loss:0.007038063059250514
# train_epoch:4|batch_idx:10|train_loss:0.007704568610471837
# train_epoch:4|batch_idx:11|train_loss:0.008383537794268408
# train_epoch:4|batch_idx:12|train_loss:0.009026805902349538
# train_epoch:4|batch_idx:13|train_loss:0.00968371509489688
# train_epoch:4|batch_idx:14|train_loss:0.010289271142375604
# train_epoch:4|batch_idx:15|train_loss:0.010890873687134848
# train_epoch:4|batch_idx:16|train_loss:0.011472979253465002
# train_epoch:4|batch_idx:17|train_loss:0.012040441450865372
# train_epoch:4|batch_idx:18|train_loss:0.012599307122409985
# train_epoch:4|batch_idx:19|train_loss:0.013123537116545313
# train_epoch:4|batch_idx:20|train_loss:0.013653326387468138
# train_epoch:4|batch_idx:21|train_loss:0.014162506791763008
# train_epoch:4|batch_idx:22|train_loss:0.014670975007039984
# train_epoch:4|batch_idx:23|train_loss:0.015151125435926477
# train_epoch:4|batch_idx:24|train_loss:0.01563218070401086
# train_epoch:4|batch_idx:25|train_loss:0.016066459976136684
# train_epoch:5|batch_idx:2|train_loss:0.0012040718951646019
# train_epoch:5|batch_idx:3|train_loss:0.001784222869618425
# train_epoch:5|batch_idx:4|train_loss:0.002325634686992719
# train_epoch:5|batch_idx:5|train_loss:0.00287544262551126
# train_epoch:5|batch_idx:6|train_loss:0.003421776348127509
# train_epoch:5|batch_idx:7|train_loss:0.003950013805215604
# train_epoch:5|batch_idx:8|train_loss:0.004454872225997625
# train_epoch:5|batch_idx:9|train_loss:0.004938772717200288
# train_epoch:5|batch_idx:10|train_loss:0.005389887602491812
# train_epoch:5|batch_idx:11|train_loss:0.005860295280948415
# train_epoch:5|batch_idx:12|train_loss:0.00630634866787919
# train_epoch:5|batch_idx:13|train_loss:0.006729723012025377
# train_epoch:5|batch_idx:14|train_loss:0.007123501481194245
# train_epoch:5|batch_idx:15|train_loss:0.007545935200608295
# train_epoch:5|batch_idx:16|train_loss:0.007920460903952861
# train_epoch:5|batch_idx:17|train_loss:0.008314174528305348
# train_epoch:5|batch_idx:18|train_loss:0.008646593160801014
# train_epoch:5|batch_idx:19|train_loss:0.009020857888610423
# train_epoch:5|batch_idx:20|train_loss:0.009352319470296303
# train_epoch:5|batch_idx:21|train_loss:0.009699752323391023
# train_epoch:5|batch_idx:22|train_loss:0.010008222286085614
# train_epoch:5|batch_idx:23|train_loss:0.010311781027452732
# train_epoch:5|batch_idx:24|train_loss:0.010604479860874915
# train_epoch:5|batch_idx:25|train_loss:0.010834780752658844
# train_epoch:6|batch_idx:2|train_loss:0.0006197011024933162
# train_epoch:6|batch_idx:3|train_loss:0.0009068750368896872
# train_epoch:6|batch_idx:4|train_loss:0.0011865672503792962
# train_epoch:6|batch_idx:5|train_loss:0.0014532958945402733
# train_epoch:6|batch_idx:6|train_loss:0.0017058907631244367
# train_epoch:6|batch_idx:7|train_loss:0.0019572129981084304
# train_epoch:6|batch_idx:8|train_loss:0.00216173736336536
# train_epoch:6|batch_idx:9|train_loss:0.0023764198534746666
# train_epoch:6|batch_idx:10|train_loss:0.002582010047303306
# train_epoch:6|batch_idx:11|train_loss:0.0027720590039868563
# train_epoch:6|batch_idx:12|train_loss:0.002947406625769434
# train_epoch:6|batch_idx:13|train_loss:0.0031156967785479365
# train_epoch:6|batch_idx:14|train_loss:0.0032766594437600898
# train_epoch:6|batch_idx:15|train_loss:0.0034235961735248565
# train_epoch:6|batch_idx:16|train_loss:0.0035744450378713878
# train_epoch:6|batch_idx:17|train_loss:0.0036909214129120533
# train_epoch:6|batch_idx:18|train_loss:0.0038153300960580786
# train_epoch:6|batch_idx:19|train_loss:0.0039380142827414805
# train_epoch:6|batch_idx:20|train_loss:0.004048094962691438
# train_epoch:6|batch_idx:21|train_loss:0.004165907377657825
# train_epoch:6|batch_idx:22|train_loss:0.004273740587388577
# train_epoch:6|batch_idx:23|train_loss:0.0043610222260090144
# train_epoch:6|batch_idx:24|train_loss:0.0044676510229606755
# train_epoch:6|batch_idx:25|train_loss:0.004571415161093076
# train_epoch:7|batch_idx:2|train_loss:0.00022148387506604195
# train_epoch:7|batch_idx:3|train_loss:0.0003252402921907263
# train_epoch:7|batch_idx:4|train_loss:0.0004312882272454051
# train_epoch:7|batch_idx:5|train_loss:0.0005202322176867916
# train_epoch:7|batch_idx:6|train_loss:0.0006142946688506084
# train_epoch:7|batch_idx:7|train_loss:0.0007103856261463682
# train_epoch:7|batch_idx:8|train_loss:0.0007975851716120032
# train_epoch:7|batch_idx:9|train_loss:0.0008953559159670236
# train_epoch:7|batch_idx:10|train_loss:0.00098843511659652
# train_epoch:7|batch_idx:11|train_loss:0.0010758656082871538
# train_epoch:7|batch_idx:12|train_loss:0.001149301974815719
# train_epoch:7|batch_idx:13|train_loss:0.0012288430042884833
# train_epoch:7|batch_idx:14|train_loss:0.001299496865036284
# train_epoch:7|batch_idx:15|train_loss:0.0013787622478875247
# train_epoch:7|batch_idx:16|train_loss:0.0014472508309296816
# train_epoch:7|batch_idx:17|train_loss:0.0015099293546762295
# train_epoch:7|batch_idx:18|train_loss:0.0015745143838492887
# train_epoch:7|batch_idx:19|train_loss:0.0016382908250188687
# train_epoch:7|batch_idx:20|train_loss:0.0017010608030592694
# train_epoch:7|batch_idx:21|train_loss:0.001758797889390187
# train_epoch:7|batch_idx:22|train_loss:0.001817765120460197
# train_epoch:7|batch_idx:23|train_loss:0.0018809456324387836
# train_epoch:7|batch_idx:24|train_loss:0.001947298458638205
# train_epoch:7|batch_idx:25|train_loss:0.0020325320373688425
# train_epoch:8|batch_idx:2|train_loss:0.0001381925270382294
# train_epoch:8|batch_idx:3|train_loss:0.00019821700943487415
# train_epoch:8|batch_idx:4|train_loss:0.0002641111518667397
# train_epoch:8|batch_idx:5|train_loss:0.0003317473404523399
# train_epoch:8|batch_idx:6|train_loss:0.0003883368001211414
# train_epoch:8|batch_idx:7|train_loss:0.0004540479557772914
# train_epoch:8|batch_idx:8|train_loss:0.0005189359106652723
# train_epoch:8|batch_idx:9|train_loss:0.0005882679909953605
# train_epoch:8|batch_idx:10|train_loss:0.0006486063722420383
# train_epoch:8|batch_idx:11|train_loss:0.0007121452851401221
# train_epoch:8|batch_idx:12|train_loss:0.000777428421904059
# train_epoch:8|batch_idx:13|train_loss:0.0008308970260414038
# train_epoch:8|batch_idx:14|train_loss:0.000880257916395311
# train_epoch:8|batch_idx:15|train_loss:0.000932077602728417
# train_epoch:8|batch_idx:16|train_loss:0.0009740864692246102
# train_epoch:8|batch_idx:17|train_loss:0.001033322269601437
# train_epoch:8|batch_idx:18|train_loss:0.0010786605371557987
# train_epoch:8|batch_idx:19|train_loss:0.0011304937034230871
# train_epoch:8|batch_idx:20|train_loss:0.0011803127204378446
# train_epoch:8|batch_idx:21|train_loss:0.001229995733355077
# train_epoch:8|batch_idx:22|train_loss:0.0012742442499638208
# train_epoch:8|batch_idx:23|train_loss:0.0013148153783998104
# train_epoch:8|batch_idx:24|train_loss:0.00136259960094888
# train_epoch:8|batch_idx:25|train_loss:0.00140180888120085
# train_epoch:9|batch_idx:2|train_loss:0.00011748337362072255
# train_epoch:9|batch_idx:3|train_loss:0.00017665910621728802
# train_epoch:9|batch_idx:4|train_loss:0.00022530075454828787
# train_epoch:9|batch_idx:5|train_loss:0.00028476884543168833
# train_epoch:9|batch_idx:6|train_loss:0.0003392629244012161
# train_epoch:9|batch_idx:7|train_loss:0.0003749738348387002
# train_epoch:9|batch_idx:8|train_loss:0.00041941350299076963
# train_epoch:9|batch_idx:9|train_loss:0.00046229535606845715
# train_epoch:9|batch_idx:10|train_loss:0.0005177783225441263
# train_epoch:9|batch_idx:11|train_loss:0.0005598198467980346
# train_epoch:9|batch_idx:12|train_loss:0.0006034883103807861
# train_epoch:9|batch_idx:13|train_loss:0.0006464468730622334
# train_epoch:9|batch_idx:14|train_loss:0.0006868589874008827
# train_epoch:9|batch_idx:15|train_loss:0.0007280857778739098
# train_epoch:9|batch_idx:16|train_loss:0.0007737184059806168
# train_epoch:9|batch_idx:17|train_loss:0.0008098843661973828
# train_epoch:9|batch_idx:18|train_loss:0.0008548029309668399
# train_epoch:9|batch_idx:19|train_loss:0.0009030376595006958
# train_epoch:9|batch_idx:20|train_loss:0.0009441245495426384
# train_epoch:9|batch_idx:21|train_loss:0.000982758384703646
# train_epoch:9|batch_idx:22|train_loss:0.0010253145246187578
# train_epoch:9|batch_idx:23|train_loss:0.001071088180998382
# train_epoch:9|batch_idx:24|train_loss:0.001109023401763157
# train_epoch:9|batch_idx:25|train_loss:0.0011436490528285504
# train_epoch:10|batch_idx:2|train_loss:0.00010245092754715865
# train_epoch:10|batch_idx:3|train_loss:0.00014914630242345627
# train_epoch:10|batch_idx:4|train_loss:0.0001816892280654095
# train_epoch:10|batch_idx:5|train_loss:0.00022421524981441706
# train_epoch:10|batch_idx:6|train_loss:0.000264514588400141
# train_epoch:10|batch_idx:7|train_loss:0.0003022049545663698
# train_epoch:10|batch_idx:8|train_loss:0.00034667289707921605
# train_epoch:10|batch_idx:9|train_loss:0.0003803873506303017
# train_epoch:10|batch_idx:10|train_loss:0.0004186215711400864
# train_epoch:10|batch_idx:11|train_loss:0.0004506650641244852
# train_epoch:10|batch_idx:12|train_loss:0.0004931510375018864
# train_epoch:10|batch_idx:13|train_loss:0.0005327108347428447
# train_epoch:10|batch_idx:14|train_loss:0.0005628832179476277
# train_epoch:10|batch_idx:15|train_loss:0.0005987542002306631
# train_epoch:10|batch_idx:16|train_loss:0.0006281434059823202
# train_epoch:10|batch_idx:17|train_loss:0.000664261523788133
# train_epoch:10|batch_idx:18|train_loss:0.0006946805565629477
# train_epoch:10|batch_idx:19|train_loss:0.0007313238953041738
# train_epoch:10|batch_idx:20|train_loss:0.0007658406749975925
# train_epoch:10|batch_idx:21|train_loss:0.0007928420800897406
# train_epoch:10|batch_idx:22|train_loss:0.0008293648386140343
# train_epoch:10|batch_idx:23|train_loss:0.000858756095816892
# train_epoch:10|batch_idx:24|train_loss:0.0008909736281208485
# train_epoch:10|batch_idx:25|train_loss:0.000926527151837945
# train_epoch:11|batch_idx:2|train_loss:8.632876126775665e-05
# train_epoch:11|batch_idx:3|train_loss:0.00011572011897391953
# train_epoch:11|batch_idx:4|train_loss:0.0001558905823053572
# train_epoch:11|batch_idx:5|train_loss:0.000193048405515797
# train_epoch:11|batch_idx:6|train_loss:0.00022475306650449056
# train_epoch:11|batch_idx:7|train_loss:0.0002633721589433312
# train_epoch:11|batch_idx:8|train_loss:0.00029403370328594085
# train_epoch:11|batch_idx:9|train_loss:0.00032481052966709304
# train_epoch:11|batch_idx:10|train_loss:0.00035314130453536146
# train_epoch:11|batch_idx:11|train_loss:0.0003858266284125518
# train_epoch:11|batch_idx:12|train_loss:0.0004189389345470731
# train_epoch:11|batch_idx:13|train_loss:0.0004460956837571166
# train_epoch:11|batch_idx:14|train_loss:0.00047807545739818704
# train_epoch:11|batch_idx:15|train_loss:0.0005094375988503673
# train_epoch:11|batch_idx:16|train_loss:0.0005429820857830066
# train_epoch:11|batch_idx:17|train_loss:0.0005713337090577972
# train_epoch:11|batch_idx:18|train_loss:0.0006021089476547135
# train_epoch:11|batch_idx:19|train_loss:0.0006287886369904178
# train_epoch:11|batch_idx:20|train_loss:0.0006527288489181686
# train_epoch:11|batch_idx:21|train_loss:0.0006794856562248236
# train_epoch:11|batch_idx:22|train_loss:0.0007117073178318713
# train_epoch:11|batch_idx:23|train_loss:0.0007354102145211819
# train_epoch:11|batch_idx:24|train_loss:0.0007631661333007752
# train_epoch:11|batch_idx:25|train_loss:0.0007993097484789111
# train_epoch:12|batch_idx:2|train_loss:6.0675769963634576e-05
# train_epoch:12|batch_idx:3|train_loss:8.717540269650573e-05
# train_epoch:12|batch_idx:4|train_loss:0.00012120409070857965
# train_epoch:12|batch_idx:5|train_loss:0.00015279050484033567
# train_epoch:12|batch_idx:6|train_loss:0.00018038937914785117
# train_epoch:12|batch_idx:7|train_loss:0.00021023620811707163
# train_epoch:12|batch_idx:8|train_loss:0.00023803271043900886
# train_epoch:12|batch_idx:9|train_loss:0.0002662155787053872
# train_epoch:12|batch_idx:10|train_loss:0.00029124802043824867
# train_epoch:12|batch_idx:11|train_loss:0.00032148391848521216
# train_epoch:12|batch_idx:12|train_loss:0.00034637883214688883
# train_epoch:12|batch_idx:13|train_loss:0.0003720505855097953
# train_epoch:12|batch_idx:14|train_loss:0.000397159202365933
# train_epoch:12|batch_idx:15|train_loss:0.0004229702472943684
# train_epoch:12|batch_idx:16|train_loss:0.000446293022982853
# train_epoch:12|batch_idx:17|train_loss:0.0004753554973445118
# train_epoch:12|batch_idx:18|train_loss:0.0005043982575828711
# train_epoch:12|batch_idx:19|train_loss:0.000529046149823029
# train_epoch:12|batch_idx:20|train_loss:0.0005506929104863587
# train_epoch:12|batch_idx:21|train_loss:0.0005721605659739391
# train_epoch:12|batch_idx:22|train_loss:0.0005964643293709466
# train_epoch:12|batch_idx:23|train_loss:0.0006220099803735346
# train_epoch:12|batch_idx:24|train_loss:0.0006484132926649473
# train_epoch:12|batch_idx:25|train_loss:0.0006878007606913646
# train_epoch:13|batch_idx:2|train_loss:5.303366596977048e-05
# train_epoch:13|batch_idx:3|train_loss:7.80751381573504e-05
# train_epoch:13|batch_idx:4|train_loss:0.00010762357545134269
# train_epoch:13|batch_idx:5|train_loss:0.0001299837909516741
# train_epoch:13|batch_idx:6|train_loss:0.00015429937238104982
# train_epoch:13|batch_idx:7|train_loss:0.0001787407360121559
# train_epoch:13|batch_idx:8|train_loss:0.00020841333724848636
# train_epoch:13|batch_idx:9|train_loss:0.00023368584191046872
# train_epoch:13|batch_idx:10|train_loss:0.0002602580333909681
# train_epoch:13|batch_idx:11|train_loss:0.00028560249512218585
# train_epoch:13|batch_idx:12|train_loss:0.0003104430730812825
# train_epoch:13|batch_idx:13|train_loss:0.0003303718878128848
# train_epoch:13|batch_idx:14|train_loss:0.00035236964215803297
# train_epoch:13|batch_idx:15|train_loss:0.00038207115989828867
# train_epoch:13|batch_idx:16|train_loss:0.00040456495849014836
# train_epoch:13|batch_idx:17|train_loss:0.0004322332174338001
# train_epoch:13|batch_idx:18|train_loss:0.0004569561478429995
# train_epoch:13|batch_idx:19|train_loss:0.0004792969533735682
# train_epoch:13|batch_idx:20|train_loss:0.0004983312421245501
# train_epoch:13|batch_idx:21|train_loss:0.000521370752299686
# train_epoch:13|batch_idx:22|train_loss:0.0005429940737830185
# train_epoch:13|batch_idx:23|train_loss:0.0005689667589708747
# train_epoch:13|batch_idx:24|train_loss:0.0005890133238776967
# train_epoch:13|batch_idx:25|train_loss:0.0006148019461677624
# train_epoch:14|batch_idx:2|train_loss:4.291847570363535e-05
# train_epoch:14|batch_idx:3|train_loss:6.456637510848117e-05
# train_epoch:14|batch_idx:4|train_loss:9.398191380328683e-05
# train_epoch:14|batch_idx:5|train_loss:0.00011757179727834282
# train_epoch:14|batch_idx:6|train_loss:0.00014201651420162883
# train_epoch:14|batch_idx:7|train_loss:0.00016228749461651566
# train_epoch:14|batch_idx:8|train_loss:0.00018331268103094072
# train_epoch:14|batch_idx:9|train_loss:0.00020522265945990644
# train_epoch:14|batch_idx:10|train_loss:0.00022941772172700112
# train_epoch:14|batch_idx:11|train_loss:0.00024853823595635946
# train_epoch:14|batch_idx:12|train_loss:0.0002749794845411261
# train_epoch:14|batch_idx:13|train_loss:0.00029737170862816493
# train_epoch:14|batch_idx:14|train_loss:0.00032404407441264407
# train_epoch:14|batch_idx:15|train_loss:0.0003519287415067939
# train_epoch:14|batch_idx:16|train_loss:0.0003794109000881746
# train_epoch:14|batch_idx:17|train_loss:0.00039761161638630763
# train_epoch:14|batch_idx:18|train_loss:0.0004218894032538806
# train_epoch:14|batch_idx:19|train_loss:0.000440080736785434
# train_epoch:14|batch_idx:20|train_loss:0.0004667185867826144
# train_epoch:14|batch_idx:21|train_loss:0.0004841081012104977
# train_epoch:14|batch_idx:22|train_loss:0.0005018494295906436
# train_epoch:14|batch_idx:23|train_loss:0.0005225656144642111
# train_epoch:14|batch_idx:24|train_loss:0.0005427255578082919
# train_epoch:14|batch_idx:25|train_loss:0.0005585396702268294
# train_epoch:15|batch_idx:2|train_loss:4.39409076617184e-05
# train_epoch:15|batch_idx:3|train_loss:6.509646140144499e-05
# train_epoch:15|batch_idx:4|train_loss:8.308888007860399e-05
# train_epoch:15|batch_idx:5|train_loss:0.00010276791495336614
# train_epoch:15|batch_idx:6|train_loss:0.00012500449659281901
# train_epoch:15|batch_idx:7|train_loss:0.0001464578158715192
# train_epoch:15|batch_idx:8|train_loss:0.0001677440794174398
# train_epoch:15|batch_idx:9|train_loss:0.0001855288025168157
# train_epoch:15|batch_idx:10|train_loss:0.00020920698039440645
# train_epoch:15|batch_idx:11|train_loss:0.00022986889597534143
# train_epoch:15|batch_idx:12|train_loss:0.00024953895011782973
# train_epoch:15|batch_idx:13|train_loss:0.0002703854016261817
# train_epoch:15|batch_idx:14|train_loss:0.00029025233995455963
# train_epoch:15|batch_idx:15|train_loss:0.00030513937546782296
# train_epoch:15|batch_idx:16|train_loss:0.00032644776393318434
# train_epoch:15|batch_idx:17|train_loss:0.00034521534602469903
# train_epoch:15|batch_idx:18|train_loss:0.0003629661603000663
# train_epoch:15|batch_idx:19|train_loss:0.0003833103821509414
# train_epoch:15|batch_idx:20|train_loss:0.00040237726014409516
# train_epoch:15|batch_idx:21|train_loss:0.00042287317654394075
# train_epoch:15|batch_idx:22|train_loss:0.00044033362565221645
# train_epoch:15|batch_idx:23|train_loss:0.0004566378576865784
# train_epoch:15|batch_idx:24|train_loss:0.0004757170958872785
# train_epoch:15|batch_idx:25|train_loss:0.000496776652832826
# train_epoch:16|batch_idx:2|train_loss:3.594619935916969e-05
# train_epoch:16|batch_idx:3|train_loss:5.764112236204917e-05
# train_epoch:16|batch_idx:4|train_loss:7.9142864754222e-05
# train_epoch:16|batch_idx:5|train_loss:9.734733765454669e-05
# train_epoch:16|batch_idx:6|train_loss:0.0001172857662159314
# train_epoch:16|batch_idx:7|train_loss:0.00013588052194233964
# train_epoch:16|batch_idx:8|train_loss:0.0001537651005967012
# train_epoch:16|batch_idx:9|train_loss:0.0001718362582323607
# train_epoch:16|batch_idx:10|train_loss:0.00018993096861552881
# train_epoch:16|batch_idx:11|train_loss:0.00020771060462249685
# train_epoch:16|batch_idx:12|train_loss:0.00023043499200650579
# train_epoch:16|batch_idx:13|train_loss:0.0002488212314309533
# train_epoch:16|batch_idx:14|train_loss:0.0002662556983319837
# train_epoch:16|batch_idx:15|train_loss:0.0002819365427757685
# train_epoch:16|batch_idx:16|train_loss:0.00029889559206526604
# train_epoch:16|batch_idx:17|train_loss:0.0003158888216510567
# train_epoch:16|batch_idx:18|train_loss:0.0003308153903211346
# train_epoch:16|batch_idx:19|train_loss:0.00034999190286028807
# train_epoch:16|batch_idx:20|train_loss:0.00036818223616367655
# train_epoch:16|batch_idx:21|train_loss:0.0003841259643774141
# train_epoch:16|batch_idx:22|train_loss:0.00040209253954346893
# train_epoch:16|batch_idx:23|train_loss:0.0004174160249250468
# train_epoch:16|batch_idx:24|train_loss:0.0004334514482147562
# train_epoch:16|batch_idx:25|train_loss:0.0004470428521744907
# train_epoch:17|batch_idx:2|train_loss:3.530857945556071e-05
# train_epoch:17|batch_idx:3|train_loss:5.121315683864482e-05
# train_epoch:17|batch_idx:4|train_loss:7.107250258732255e-05
# train_epoch:17|batch_idx:5|train_loss:8.854903510691207e-05
# train_epoch:17|batch_idx:6|train_loss:0.00010810411659073947
# train_epoch:17|batch_idx:7|train_loss:0.00012558397175675527
# train_epoch:17|batch_idx:8|train_loss:0.00014641972637607478
# train_epoch:17|batch_idx:9|train_loss:0.00016275910013935967
# train_epoch:17|batch_idx:10|train_loss:0.00017755649893022165
# train_epoch:17|batch_idx:11|train_loss:0.00019371429222597402
# train_epoch:17|batch_idx:12|train_loss:0.000210845199847612
# train_epoch:17|batch_idx:13|train_loss:0.0002273758895893651
# train_epoch:17|batch_idx:14|train_loss:0.0002475780376417625
# train_epoch:17|batch_idx:15|train_loss:0.0002652505019971405
# train_epoch:17|batch_idx:16|train_loss:0.0002882604301423551
# train_epoch:17|batch_idx:17|train_loss:0.0003042833531181589
# train_epoch:17|batch_idx:18|train_loss:0.00032171253315462737
# train_epoch:17|batch_idx:19|train_loss:0.00033643342963550997
# train_epoch:17|batch_idx:20|train_loss:0.0003528310340784845
# train_epoch:17|batch_idx:21|train_loss:0.0003706693843962744
# train_epoch:17|batch_idx:22|train_loss:0.00038729072438102764
# train_epoch:17|batch_idx:23|train_loss:0.00040164932467695103
# train_epoch:17|batch_idx:24|train_loss:0.00041577469157757905
# train_epoch:17|batch_idx:25|train_loss:0.00042845799204181223
# train_epoch:18|batch_idx:2|train_loss:3.184050330303313e-05
# train_epoch:18|batch_idx:3|train_loss:4.7926787748306156e-05
# train_epoch:18|batch_idx:4|train_loss:6.152851081568322e-05
# train_epoch:18|batch_idx:5|train_loss:8.117773916658967e-05
# train_epoch:18|batch_idx:6|train_loss:9.667234205729448e-05
# train_epoch:18|batch_idx:7|train_loss:0.00011541643740471315
# train_epoch:18|batch_idx:8|train_loss:0.00013160597808297732
# train_epoch:18|batch_idx:9|train_loss:0.00014824806905699216
# train_epoch:18|batch_idx:10|train_loss:0.00016137905119136832
# train_epoch:18|batch_idx:11|train_loss:0.00017596886454816532
# train_epoch:18|batch_idx:12|train_loss:0.00019347789064390707
# train_epoch:18|batch_idx:13|train_loss:0.00020769888590425932
# train_epoch:18|batch_idx:14|train_loss:0.00022612618927362298
# train_epoch:18|batch_idx:15|train_loss:0.00024146655553274534
# train_epoch:18|batch_idx:16|train_loss:0.00025956466046421706
# train_epoch:18|batch_idx:17|train_loss:0.00027408735611690924
# train_epoch:18|batch_idx:18|train_loss:0.0002878648207920265
# train_epoch:18|batch_idx:19|train_loss:0.0003029372467583901
# train_epoch:18|batch_idx:20|train_loss:0.0003211960029066279
# train_epoch:18|batch_idx:21|train_loss:0.0003385115581911241
# train_epoch:18|batch_idx:22|train_loss:0.0003534929422657495
# train_epoch:18|batch_idx:23|train_loss:0.00037151798564341983
# train_epoch:18|batch_idx:24|train_loss:0.00038525599048769553
# train_epoch:18|batch_idx:25|train_loss:0.00039855728443298076
# train_epoch:19|batch_idx:2|train_loss:3.2655906088782094e-05
# train_epoch:19|batch_idx:3|train_loss:4.912348398342564e-05
# train_epoch:19|batch_idx:4|train_loss:6.617064431867673e-05
# train_epoch:19|batch_idx:5|train_loss:8.093219884968066e-05
# train_epoch:19|batch_idx:6|train_loss:9.865893496265798e-05
# train_epoch:19|batch_idx:7|train_loss:0.00011339399013953605
# train_epoch:19|batch_idx:8|train_loss:0.00012915918204982208
# train_epoch:19|batch_idx:9|train_loss:0.0001428999769661681
# train_epoch:19|batch_idx:10|train_loss:0.00015790782889108296
# train_epoch:19|batch_idx:11|train_loss:0.0001723199947424023
# train_epoch:19|batch_idx:12|train_loss:0.00018729233521629465
# train_epoch:19|batch_idx:13|train_loss:0.00020203310553764937
# train_epoch:19|batch_idx:14|train_loss:0.00021501274373992505
# train_epoch:19|batch_idx:15|train_loss:0.00022696070673484955
# train_epoch:19|batch_idx:16|train_loss:0.00024007768729949458
# train_epoch:19|batch_idx:17|train_loss:0.0002537125540095555
# train_epoch:19|batch_idx:18|train_loss:0.0002670755050678411
# train_epoch:19|batch_idx:19|train_loss:0.0002801203524380096
# train_epoch:19|batch_idx:20|train_loss:0.00029902243590418327
# train_epoch:19|batch_idx:21|train_loss:0.0003122225890208961
# train_epoch:19|batch_idx:22|train_loss:0.00032578089957172843
# train_epoch:19|batch_idx:23|train_loss:0.0003428433915446601
# train_epoch:19|batch_idx:24|train_loss:0.0003573653673289446
# train_epoch:19|batch_idx:25|train_loss:0.0003698997219142161
# train_epoch:20|batch_idx:2|train_loss:3.020245429573569e-05
# train_epoch:20|batch_idx:3|train_loss:4.628207339714262e-05
# train_epoch:20|batch_idx:4|train_loss:6.085640064485387e-05
# train_epoch:20|batch_idx:5|train_loss:7.750953470046322e-05
# train_epoch:20|batch_idx:6|train_loss:9.082640248221073e-05
# train_epoch:20|batch_idx:7|train_loss:0.00010358462983518221
# train_epoch:20|batch_idx:8|train_loss:0.0001153583025201137
# train_epoch:20|batch_idx:9|train_loss:0.00012842956199195268
# train_epoch:20|batch_idx:10|train_loss:0.00014261649921536445
# train_epoch:20|batch_idx:11|train_loss:0.00015615767975617583
# train_epoch:20|batch_idx:12|train_loss:0.00016928573274789895
# train_epoch:20|batch_idx:13|train_loss:0.00018294078114702077
# train_epoch:20|batch_idx:14|train_loss:0.00019458939696534523
# train_epoch:20|batch_idx:15|train_loss:0.00020924116655880092
# train_epoch:20|batch_idx:16|train_loss:0.00022160584797471943
# train_epoch:20|batch_idx:17|train_loss:0.0002363795571680355
# train_epoch:20|batch_idx:18|train_loss:0.0002512695120447306
# train_epoch:20|batch_idx:19|train_loss:0.0002625028278512752
# train_epoch:20|batch_idx:20|train_loss:0.0002756720239465887
# train_epoch:20|batch_idx:21|train_loss:0.00028823360879605094
# train_epoch:20|batch_idx:22|train_loss:0.0003027951502254311
# train_epoch:20|batch_idx:23|train_loss:0.0003162187900035137
# train_epoch:20|batch_idx:24|train_loss:0.0003282686430430842
# train_epoch:20|batch_idx:25|train_loss:0.00034008734952658415
# train_epoch:21|batch_idx:2|train_loss:2.6323390100522345e-05
# train_epoch:21|batch_idx:3|train_loss:3.9783513791873964e-05
# train_epoch:21|batch_idx:4|train_loss:5.311113024603516e-05
# train_epoch:21|batch_idx:5|train_loss:6.653546162023402e-05
# train_epoch:21|batch_idx:6|train_loss:7.820621007692672e-05
# train_epoch:21|batch_idx:7|train_loss:8.900555886724997e-05
# train_epoch:21|batch_idx:8|train_loss:0.00010272765561468958
# train_epoch:21|batch_idx:9|train_loss:0.00011636377156717605
# train_epoch:21|batch_idx:10|train_loss:0.00012911407587428886
# train_epoch:21|batch_idx:11|train_loss:0.00014200294845958045
# train_epoch:21|batch_idx:12|train_loss:0.00015253140281856759
# train_epoch:21|batch_idx:13|train_loss:0.00016492947057383334
# train_epoch:21|batch_idx:14|train_loss:0.00018170737781007465
# train_epoch:21|batch_idx:15|train_loss:0.00019311767469332056
# train_epoch:21|batch_idx:16|train_loss:0.00020531962387437044
# train_epoch:21|batch_idx:17|train_loss:0.00021625242720230175
# train_epoch:21|batch_idx:18|train_loss:0.0002266555156156018
# train_epoch:21|batch_idx:19|train_loss:0.00023906947129723655
# train_epoch:21|batch_idx:20|train_loss:0.00025327534396917776
# train_epoch:21|batch_idx:21|train_loss:0.0002649608988765334
# train_epoch:21|batch_idx:22|train_loss:0.0002782210374029774
# train_epoch:21|batch_idx:23|train_loss:0.0002897642517238001
# train_epoch:21|batch_idx:24|train_loss:0.00030384117378391153
# train_epoch:21|batch_idx:25|train_loss:0.00032100186727586247
# train_epoch:22|batch_idx:2|train_loss:2.7505522752905255e-05
# train_epoch:22|batch_idx:3|train_loss:3.984695032351848e-05
# train_epoch:22|batch_idx:4|train_loss:5.253855163664583e-05
# train_epoch:22|batch_idx:5|train_loss:6.632513612649351e-05
# train_epoch:22|batch_idx:6|train_loss:7.921095372733648e-05
# train_epoch:22|batch_idx:7|train_loss:9.364657335095388e-05
# train_epoch:22|batch_idx:8|train_loss:0.00010744207861918894
# train_epoch:22|batch_idx:9|train_loss:0.00012151970116470414
# train_epoch:22|batch_idx:10|train_loss:0.00013809850892034648
# train_epoch:22|batch_idx:11|train_loss:0.0001523012986907096
# train_epoch:22|batch_idx:12|train_loss:0.0001640613641749436
# train_epoch:22|batch_idx:13|train_loss:0.00017554783106514955
# train_epoch:22|batch_idx:14|train_loss:0.0001861352114100182
# train_epoch:22|batch_idx:15|train_loss:0.00019769356586039067
# train_epoch:22|batch_idx:16|train_loss:0.00020902533111697864
# train_epoch:22|batch_idx:17|train_loss:0.00022089208314724515
# train_epoch:22|batch_idx:18|train_loss:0.00023175403390004272
# train_epoch:22|batch_idx:19|train_loss:0.00024301860899226193
# train_epoch:22|batch_idx:20|train_loss:0.0002535525538505764
# train_epoch:22|batch_idx:21|train_loss:0.0002637456653933058
# train_epoch:22|batch_idx:22|train_loss:0.0002740138870965301
# train_epoch:22|batch_idx:23|train_loss:0.0002854592073368874
# train_epoch:22|batch_idx:24|train_loss:0.00029611992285008424
# train_epoch:22|batch_idx:25|train_loss:0.00030597247183322907
# train_epoch:23|batch_idx:2|train_loss:2.5044623897343442e-05
# train_epoch:23|batch_idx:3|train_loss:3.82914775426737e-05
# train_epoch:23|batch_idx:4|train_loss:4.806902952196366e-05
# train_epoch:23|batch_idx:5|train_loss:6.181681193075739e-05
# train_epoch:23|batch_idx:6|train_loss:7.426552223242658e-05
# train_epoch:23|batch_idx:7|train_loss:8.551947876168967e-05
# train_epoch:23|batch_idx:8|train_loss:9.624629471731442e-05
# train_epoch:23|batch_idx:9|train_loss:0.00010717970490695538
# train_epoch:23|batch_idx:10|train_loss:0.0001187661346713347
# train_epoch:23|batch_idx:11|train_loss:0.00012976650493933342
# train_epoch:23|batch_idx:12|train_loss:0.0001414245743556379
# train_epoch:23|batch_idx:13|train_loss:0.00015297656892062717
# train_epoch:23|batch_idx:14|train_loss:0.00016270140235490621
# train_epoch:23|batch_idx:15|train_loss:0.0001736845516195867
# train_epoch:23|batch_idx:16|train_loss:0.00018444088906339326
# train_epoch:23|batch_idx:17|train_loss:0.00019599562116637433
# train_epoch:23|batch_idx:18|train_loss:0.0002078930962122452
# train_epoch:23|batch_idx:19|train_loss:0.0002197550408385026
# train_epoch:23|batch_idx:20|train_loss:0.0002310786886434806
# train_epoch:23|batch_idx:21|train_loss:0.00024338929804658513
# train_epoch:23|batch_idx:22|train_loss:0.00025332642481434387
# train_epoch:23|batch_idx:23|train_loss:0.00026293956783533513
# train_epoch:23|batch_idx:24|train_loss:0.0002733118919727071
# train_epoch:23|batch_idx:25|train_loss:0.00028847334339566854
# train_epoch:24|batch_idx:2|train_loss:2.0079833634546354e-05
# train_epoch:24|batch_idx:3|train_loss:3.1021737032747184e-05
# train_epoch:24|batch_idx:4|train_loss:4.1402668076115365e-05
# train_epoch:24|batch_idx:5|train_loss:5.514193567094104e-05
# train_epoch:24|batch_idx:6|train_loss:6.654747183115676e-05
# train_epoch:24|batch_idx:7|train_loss:8.043805713352468e-05
# train_epoch:24|batch_idx:8|train_loss:9.375344163148726e-05
# train_epoch:24|batch_idx:9|train_loss:0.00010565618349698512
# train_epoch:24|batch_idx:10|train_loss:0.00011606642132640903
# train_epoch:24|batch_idx:11|train_loss:0.0001267885849668101
# train_epoch:24|batch_idx:12|train_loss:0.0001398565722042393
# train_epoch:24|batch_idx:13|train_loss:0.00014955576962227523
# train_epoch:24|batch_idx:14|train_loss:0.0001613495425528298
# train_epoch:24|batch_idx:15|train_loss:0.0001715383168815051
# train_epoch:24|batch_idx:16|train_loss:0.0001804207974821077
# train_epoch:24|batch_idx:17|train_loss:0.00018980732184482386
# train_epoch:24|batch_idx:18|train_loss:0.00020169347138293276
# train_epoch:24|batch_idx:19|train_loss:0.00021228792854531445
# train_epoch:24|batch_idx:20|train_loss:0.00022313942851013497
# train_epoch:24|batch_idx:21|train_loss:0.00023213008515561787
# train_epoch:24|batch_idx:22|train_loss:0.00024397128887187496
# train_epoch:24|batch_idx:23|train_loss:0.000253342035970959
# train_epoch:24|batch_idx:24|train_loss:0.00026361024915201836
# train_epoch:24|batch_idx:25|train_loss:0.0002724104894635578
# train_epoch:25|batch_idx:2|train_loss:2.0611899722355148e-05
# train_epoch:25|batch_idx:3|train_loss:3.0480099727660666e-05
# train_epoch:25|batch_idx:4|train_loss:4.10300867619696e-05
# train_epoch:25|batch_idx:5|train_loss:5.360643710356113e-05
# train_epoch:25|batch_idx:6|train_loss:6.457327837401097e-05
# train_epoch:25|batch_idx:7|train_loss:7.501671618522686e-05
# train_epoch:25|batch_idx:8|train_loss:8.510930025582446e-05
# train_epoch:25|batch_idx:9|train_loss:9.691369473591619e-05
# train_epoch:25|batch_idx:10|train_loss:0.00010571928740646996
# train_epoch:25|batch_idx:11|train_loss:0.00011612274630662853
# train_epoch:25|batch_idx:12|train_loss:0.0001270879521125964
# train_epoch:25|batch_idx:13|train_loss:0.00013750069432847846
# train_epoch:25|batch_idx:14|train_loss:0.0001467171804645745
# train_epoch:25|batch_idx:15|train_loss:0.00015562900864496464
# train_epoch:25|batch_idx:16|train_loss:0.00016667081236645774
# train_epoch:25|batch_idx:17|train_loss:0.00017541195937648198
# train_epoch:25|batch_idx:18|train_loss:0.00018511030108676952
# train_epoch:25|batch_idx:19|train_loss:0.00019585956580130465
# train_epoch:25|batch_idx:20|train_loss:0.00021027322678316023
# train_epoch:25|batch_idx:21|train_loss:0.00022000022946396504
# train_epoch:25|batch_idx:22|train_loss:0.00022989424197093083
# train_epoch:25|batch_idx:23|train_loss:0.00024005220859142596
# train_epoch:25|batch_idx:24|train_loss:0.0002497075638996485
# train_epoch:25|batch_idx:25|train_loss:0.0002598336726427078
# train_epoch:26|batch_idx:2|train_loss:1.8564259345261484e-05
# train_epoch:26|batch_idx:3|train_loss:2.9142338717297005e-05
# train_epoch:26|batch_idx:4|train_loss:3.9770529977088894e-05
# train_epoch:26|batch_idx:5|train_loss:5.060491625160452e-05
# train_epoch:26|batch_idx:6|train_loss:6.03014430571377e-05
# train_epoch:26|batch_idx:7|train_loss:7.003202925353676e-05
# train_epoch:26|batch_idx:8|train_loss:8.156946176106896e-05
# train_epoch:26|batch_idx:9|train_loss:9.122192756822245e-05
# train_epoch:26|batch_idx:10|train_loss:0.00010154059406105928
# train_epoch:26|batch_idx:11|train_loss:0.00011026963617933809
# train_epoch:26|batch_idx:12|train_loss:0.00012220974918016273
# train_epoch:26|batch_idx:13|train_loss:0.00013248152887816527
# train_epoch:26|batch_idx:14|train_loss:0.0001415251156662085
# train_epoch:26|batch_idx:15|train_loss:0.00015302515093935655
# train_epoch:26|batch_idx:16|train_loss:0.00016333844567912044
# train_epoch:26|batch_idx:17|train_loss:0.00017522491958584183
# train_epoch:26|batch_idx:18|train_loss:0.0001850961403367957
# train_epoch:26|batch_idx:19|train_loss:0.0001934111177608926
# train_epoch:26|batch_idx:20|train_loss:0.00020400536600355954
# train_epoch:26|batch_idx:21|train_loss:0.00021205732350932556
# train_epoch:26|batch_idx:22|train_loss:0.00022191173646029033
# train_epoch:26|batch_idx:23|train_loss:0.00023283550722731484
# train_epoch:26|batch_idx:24|train_loss:0.00024274812267952598
# train_epoch:26|batch_idx:25|train_loss:0.00025350717970958124
# train_epoch:27|batch_idx:2|train_loss:2.1203944568116608e-05
# train_epoch:27|batch_idx:3|train_loss:2.961341865007034e-05
# train_epoch:27|batch_idx:4|train_loss:3.853022684813093e-05
# train_epoch:27|batch_idx:5|train_loss:4.9715017800340216e-05
# train_epoch:27|batch_idx:6|train_loss:6.096753243515949e-05
# train_epoch:27|batch_idx:7|train_loss:7.103643021468339e-05
# train_epoch:27|batch_idx:8|train_loss:8.21349315775564e-05
# train_epoch:27|batch_idx:9|train_loss:9.051667475487827e-05
# train_epoch:27|batch_idx:10|train_loss:9.971278522050741e-05
# train_epoch:27|batch_idx:11|train_loss:0.00010911089758446466
# train_epoch:27|batch_idx:12|train_loss:0.0001175647082364361
# train_epoch:27|batch_idx:13|train_loss:0.00012681337402147406
# train_epoch:27|batch_idx:14|train_loss:0.00013800113285184805
# train_epoch:27|batch_idx:15|train_loss:0.00014736716726556755
# train_epoch:27|batch_idx:16|train_loss:0.000156187585222202
# train_epoch:27|batch_idx:17|train_loss:0.0001656521290451333
# train_epoch:27|batch_idx:18|train_loss:0.00017400594180014855
# train_epoch:27|batch_idx:19|train_loss:0.00018265559400678215
# train_epoch:27|batch_idx:20|train_loss:0.00019184477043463223
# train_epoch:27|batch_idx:21|train_loss:0.00020038422013892503
# train_epoch:27|batch_idx:22|train_loss:0.00021102544893178025
# train_epoch:27|batch_idx:23|train_loss:0.00022247343090256292
# train_epoch:27|batch_idx:24|train_loss:0.0002319601403123724
# train_epoch:27|batch_idx:25|train_loss:0.00023963948090871174
# train_epoch:28|batch_idx:2|train_loss:2.0842835516221765e-05
# train_epoch:28|batch_idx:3|train_loss:3.238696506065605e-05
# train_epoch:28|batch_idx:4|train_loss:4.481706104415506e-05
# train_epoch:28|batch_idx:5|train_loss:5.50872933886507e-05
# train_epoch:28|batch_idx:6|train_loss:6.456828775997554e-05
# train_epoch:28|batch_idx:7|train_loss:7.440781567649932e-05
# train_epoch:28|batch_idx:8|train_loss:8.34238905006935e-05
# train_epoch:28|batch_idx:9|train_loss:9.386954088395799e-05
# train_epoch:28|batch_idx:10|train_loss:0.00010249125873194123
# train_epoch:28|batch_idx:11|train_loss:0.00011178208908755821
# train_epoch:28|batch_idx:12|train_loss:0.00012073993175853114
# train_epoch:28|batch_idx:13|train_loss:0.0001281172769458228
# train_epoch:28|batch_idx:14|train_loss:0.0001371796506474603
# train_epoch:28|batch_idx:15|train_loss:0.00014446738472991233
# train_epoch:28|batch_idx:16|train_loss:0.00015302480356134312
# train_epoch:28|batch_idx:17|train_loss:0.0001641645532295194
# train_epoch:28|batch_idx:18|train_loss:0.00017368818484085464
# train_epoch:28|batch_idx:19|train_loss:0.00018440706652699183
# train_epoch:28|batch_idx:20|train_loss:0.00019298734933995514
# train_epoch:28|batch_idx:21|train_loss:0.00019991639386006128
# train_epoch:28|batch_idx:22|train_loss:0.00020986048296264972
# train_epoch:28|batch_idx:23|train_loss:0.00021829703198292193
# train_epoch:28|batch_idx:24|train_loss:0.00022644280870371794
# train_epoch:28|batch_idx:25|train_loss:0.00023667955305427312
# train_epoch:29|batch_idx:2|train_loss:1.728751012084321e-05
# train_epoch:29|batch_idx:3|train_loss:2.692264582892909e-05
# train_epoch:29|batch_idx:4|train_loss:3.638329772828993e-05
# train_epoch:29|batch_idx:5|train_loss:4.598189620895589e-05
# train_epoch:29|batch_idx:6|train_loss:5.363759508213984e-05
# train_epoch:29|batch_idx:7|train_loss:6.425759624663471e-05
# train_epoch:29|batch_idx:8|train_loss:7.20398190120856e-05
# train_epoch:29|batch_idx:9|train_loss:8.151986162021904e-05
# train_epoch:29|batch_idx:10|train_loss:8.987593923656034e-05
# train_epoch:29|batch_idx:11|train_loss:9.891573397335289e-05
# train_epoch:29|batch_idx:12|train_loss:0.00010800052544081144
# train_epoch:29|batch_idx:13|train_loss:0.00011925574073366831
# train_epoch:29|batch_idx:14|train_loss:0.00012748193449708595
# train_epoch:29|batch_idx:15|train_loss:0.000134921785756633
# train_epoch:29|batch_idx:16|train_loss:0.00014204392014539608
# train_epoch:29|batch_idx:17|train_loss:0.00015174853647935673
# train_epoch:29|batch_idx:18|train_loss:0.00016080877162557626
# train_epoch:29|batch_idx:19|train_loss:0.00017128144138297053
# train_epoch:29|batch_idx:20|train_loss:0.000180542094555373
# train_epoch:29|batch_idx:21|train_loss:0.00018981772432318176
# train_epoch:29|batch_idx:22|train_loss:0.00019793518898889958
# train_epoch:29|batch_idx:23|train_loss:0.00020593056908678546
# train_epoch:29|batch_idx:24|train_loss:0.00021460021843423667
# train_epoch:29|batch_idx:25|train_loss:0.00022158520553132585
# train_epoch:30|batch_idx:2|train_loss:1.8895640866792513e-05
# train_epoch:30|batch_idx:3|train_loss:2.771253495446437e-05
# train_epoch:30|batch_idx:4|train_loss:3.64178668998887e-05
# train_epoch:30|batch_idx:5|train_loss:4.373371205611588e-05
# train_epoch:30|batch_idx:6|train_loss:5.149166386385949e-05
# train_epoch:30|batch_idx:7|train_loss:6.055443158342701e-05
# train_epoch:30|batch_idx:8|train_loss:6.919808998338035e-05
# train_epoch:30|batch_idx:9|train_loss:7.904664808706626e-05
# train_epoch:30|batch_idx:10|train_loss:8.884757047607785e-05
# train_epoch:30|batch_idx:11|train_loss:9.67334199231118e-05
# train_epoch:30|batch_idx:12|train_loss:0.00010690677360084358
# train_epoch:30|batch_idx:13|train_loss:0.00011595541379114154
# train_epoch:30|batch_idx:14|train_loss:0.0001250332743131098
# train_epoch:30|batch_idx:15|train_loss:0.00013188819489064248
# train_epoch:30|batch_idx:16|train_loss:0.0001417279247239775
# train_epoch:30|batch_idx:17|train_loss:0.00014996062022837184
# train_epoch:30|batch_idx:18|train_loss:0.00015767738298283612
# train_epoch:30|batch_idx:19|train_loss:0.0001660294008381184
# train_epoch:30|batch_idx:20|train_loss:0.00017458286398909235
# train_epoch:30|batch_idx:21|train_loss:0.0001815700861088552
# train_epoch:30|batch_idx:22|train_loss:0.00019116361763881872
# train_epoch:30|batch_idx:23|train_loss:0.0001983280993380489
# train_epoch:30|batch_idx:24|train_loss:0.0002078089598213162
# train_epoch:30|batch_idx:25|train_loss:0.0002271045626451572

# %% [markdown]
# When you're done training, run the cells below to visualize some predictions of your model, and to compute a validation score:

# %%
show_keypoint_predictions(model, val_dataset)

# %%
print("Score:", evaluate_model(model, val_dataset))
# Out:
# Score: 33.75405051329098

# %% [markdown]
# # 3. Save Your Model for Submission
#
# If your model achieved a validation score of 100 or higher, save your model with the cell below and submit it to [the submission server](https://i2dl.vc.in.tum.de/). Your validation set is of course different from the test set on our server, so results may vary. Nevertheless, you will have a reasonable close approximation about your performance.
#
# Before that, we will check again whether the number of parameters is below 5 Mio. and the file size is below 20 MB.

# %%
save_model(model, "facial_keypoints.p")
# Out:
# 'models/facial_keypoints.p'

# %% [markdown]
# Congrats - you've now finished your first Convolution Neural Network! Simply run the following cell to create a zipped file for your implementations.

# %%
# Now zip the folder for upload
from exercise_code.util.submit import submit_exercise

submit_exercise("../output/exercise09")
# Out:
# relevant folders: ['exercise_code', 'models']
# notebooks files: ['Optional-spatial_batchnorm.ipynb', '1_facial_keypoints.ipynb']
# Adding folder exercise_code
# Adding folder models
# Adding notebook Optional-spatial_batchnorm.ipynb
# Adding notebook 1_facial_keypoints.ipynb
# Zipping successful! Zip is stored under: /Users/karo/Desktop/i2dl_exercises/output/exercise09.zip

# %% [markdown]
# # Submission Goals
#
# - Goal: Implement and train a convolution neural network for facial keypoint detection.
# - Passing Criteria: Reach **Score >= 100** on __our__ test dataset. The submission system will show you your score after you submit.
#
# - Submission start: __January 12, 2023, 13.00__
# - Submission deadline: __January 18, 2023 - 15:59__
# - You can make **$\infty$** submissions until the deadline. Your __best submission__ will be considered for bonus

# %% [markdown]
# # [Exercise Review](https://docs.google.com/forms/d/e/1FAIpQLSedSHEJ5vN-9FmJN-IGSQ9heDM_8qJQjHL4glgQGlrpQJEYPQ/viewform?usp=pp_url&entry.999074405=Exercise+9:+Facial+Keypoints)
# We are always interested in your opinion. Now that you have finished this exercise, we would like you to give us some feedback about the time required to finish the submission and/or work through the notebooks. Please take the short time to fill out our [review form](https://docs.google.com/forms/d/e/1FAIpQLSedSHEJ5vN-9FmJN-IGSQ9heDM_8qJQjHL4glgQGlrpQJEYPQ/viewform?usp=pp_url&entry.999074405=Exercise+9:+Facial+Keypoints) for this exercise so that we can do better next time! :)
